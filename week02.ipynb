# %% [markdown]
# <a href="https://colab.research.google.com/github/ririssilvia/PCVK_matrikulasi_2022/blob/main/week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow 
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np 
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg') 
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)      #konversi channel BGR-> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0) 
#simpan File image 
#cv.imrite('/content/drive/MyDrive/PCVK MM/Images/mandriLL2.tiff,img5) 

#tampiLkan pLot dengan ukuran canvas yg lebih besar 
fig = plt.figure(figsize=(10,10))       #ubah-ubah ukuran (10,10) sesuai kebutuhan 
ax = fig.add_subplot(111) 
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 ptl dan pt2 
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10) 
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15) 
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8) 
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5) 
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX 
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA) 
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32) 
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32) 
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))  # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakiLi R, G, dan B 
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5) 
plt.imshow(black_img2)

# %% [markdown]
# **JAWABN PERTANYAN MODUL 2 :**
# 1. Gambar yang memakai matplotlib akan menampilkan  visualisasi data seperti membuat plot grafik untuk Sumbu X dan Y
# 2. Perbedaan pembuatan black image antara tipe data int16
# dan int32 adalah pada ukuran, Hal tersebut dapat mempengaruhi tingkat intensitas dari suatu image.
# 3. Nilai tersebut untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakiLi R, G, dan B.Nilai -1 untuk red, 1 untuk green, dan 2 untuk blue.
# 4.  Untuk penggunaan OpenCV di Google Colab, terdapat satu fungsi yang memerlukan patch atau perbaikan, yaitu cv2.imshow(). Fungsi ini digunakan untuk menampilkan gambar pada OpenCV. Di Google Colab, fungsi ini digantikan dengan baris perintah from google.colab.patches import cv2_imshow
# 5. Skimage impot io untuk Paket Skimage memungkinkan kita untuk melakukan pemrosesan gambar menggunakan Pytho

# %% [markdown]
# **Tugas Nomer 1**

# %%
# RGB
# 0:1:2
# Red-Green
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img_rg = cv.cvtColor(img,cv.COLOR_BGR2RGB)

img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
# Green-Blue
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg') 
img_gb = cv.cvtColor(img,cv.COLOR_BGR2RGB)

img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %% [markdown]
# **Tugas Nomer 2**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg') 
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img = img_rgb[10:100,10:100]
plt.imshow(img)

# %% [markdown]
# **Tugas Nomer 3**

# %%
img_green = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_green[5:30], cmap='Greens')

# %% [markdown]
# **Tugas Nomer 4**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img_t4 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_t4, pt1=(420,400), pt2=(500,600), color=(0,255,255), thickness=10)
cv.rectangle(img_t4, pt1=(600,100), pt2=(450,200), color=(0,255,0),thickness=10)
cv.rectangle(img_t4, pt1=(400,300), pt2=(600,340), color=(255,255,255),thickness=10)
cv.rectangle(img_t4, pt1=(100,350), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_t4, pt1=(150,600), pt2=(400,550), color=(0,0,255),thickness=10)
plt.imshow(img_t4)

# %% [markdown]
# **Tugas Nomer 5**

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0) 

fig = plt.figure(figsize=(5,5))       #ubah-ubah ukuran (10,10) sesuai kebutuhan 
ax = fig.add_subplot(111) 
ax.imshow(img5)

# %% [markdown]
# **Tugas Nomer 6**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img_t6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_t6,pt1=(300,90), pt2=(500,270),color=(0,0,255),thickness=15)
cv.circle(img_t6,center=(400,180),radius=100,color=(255,0,0),thickness=8)
plt.imshow(img_t6)

# %% [markdown]
# **Tugas Nomer 7**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img_t5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_t5 ,pt1=(130,616),pt2=(10,450),color=(0,0,255),thickness=10)
plt.imshow(img_t5 )
